# %% [markdown]
# # ClimaCity Paris -- Session 5
# ## Machine Learning avec MLlib, optimisation et bilan d'architecture
#
# **Module** : Traitement de données massives avec Apache Spark et PySpark
# **Prérequis** : Sessions 2–3 terminées — la table Delta
# `data/output/delta/disponibilite` doit être présente (années 2020–2022 typiquement).
#
# **Dépendances supplémentaires** : `folium`, `mlflow` (`pip install -r requirements.txt`).
#
# ---
#
# Ce notebook couvre le Jour 3 du projet ClimaCity Paris.
#
# - **Partie 1** : Machine Learning distribué avec MLlib.
#   Construction de features, clustering des stations (K-Means), modèle de
#   prédiction du taux d'occupation (GBTRegressor), validation croisée,
#   et suivi des expériences avec MLflow.
#
# > **Convention** : les cellules `# [EXERCICE]` contiennent une consigne.
# > Les cellules `# [CORRECTION]` proposent une solution.

# %% [markdown]
# ---
# ## Section 0 -- Configuration

# %%
# Compat Python 3.12 : pyspark.ml importe encore distutils (retiré de la stdlib).
# setuptools<82 le fournit ; ce filet de sécurité évite ModuleNotFoundError sinon.
import sys
import types

try:
    from distutils.version import LooseVersion  # noqa: F401
except ModuleNotFoundError:
    class LooseVersion:  # type: ignore[no-redef]
        def __init__(self, vstring=""):
            self.vstring = str(vstring)
            # découpe simple pour les comparaisons (ex. numpy "1.9")
            parts = []
            for chunk in self.vstring.replace("-", ".").split("."):
                try:
                    parts.append(int(chunk))
                except ValueError:
                    parts.append(chunk)
            self.version = tuple(parts)

        def _cmp(self, other):
            if not isinstance(other, LooseVersion):
                other = LooseVersion(other)
            if self.version == other.version:
                return 0
            return -1 if self.version < other.version else 1

        def __eq__(self, other): return self._cmp(other) == 0
        def __lt__(self, other): return self._cmp(other) < 0
        def __le__(self, other): return self._cmp(other) <= 0
        def __gt__(self, other): return self._cmp(other) > 0
        def __ge__(self, other): return self._cmp(other) >= 0

    _distutils = types.ModuleType("distutils")
    _version = types.ModuleType("distutils.version")
    _version.LooseVersion = LooseVersion
    _distutils.version = _version
    sys.modules["distutils"] = _distutils
    sys.modules["distutils.version"] = _version

import os
import sys
import platform
import time
import warnings
from pathlib import Path

warnings.filterwarnings("ignore")

# Mac Apple Silicon : Java arm64 + workers PySpark arm64 (identique Sessions 3–4)
if platform.system() == "Darwin" and platform.machine() == "arm64":
    chemins_jdk_possibles = [
        Path("/opt/homebrew/opt/openjdk@17/libexec/openjdk.jdk/Contents/Home"),
        Path("/opt/homebrew/opt/openjdk@21/libexec/openjdk.jdk/Contents/Home"),
    ]
    chemin_java_home = next(
        (
            chemin_jdk
            for chemin_jdk in chemins_jdk_possibles
            if (chemin_jdk / "bin" / "java").exists()
        ),
        None,
    )
    if chemin_java_home:
        os.environ["JAVA_HOME"] = str(chemin_java_home)
        os.environ["PATH"] = f"{chemin_java_home / 'bin'}:{os.environ.get('PATH', '')}"
    chemin_python = Path(sys.executable)
    script_python_arm64 = chemin_python.parent / "python-arm64"
    if not script_python_arm64.exists():
        script_python_arm64.write_text(
            f'#!/bin/bash\nexec arch -arm64 "{chemin_python}" "$@"\n',
            encoding="utf-8",
        )
        script_python_arm64.chmod(0o755)
    os.environ["PYSPARK_PYTHON"] = str(script_python_arm64)
    os.environ["PYSPARK_DRIVER_PYTHON"] = str(chemin_python)

# Chemins projet ("data" à la racine, ou "../data" si cwd différent)
chemins_data_possibles = [Path("data"), Path("../data")]
DATA_DIR = next(
    (
        chemin_data
        for chemin_data in chemins_data_possibles
        if (chemin_data / "velib").exists()
    ),
    chemins_data_possibles[0],
)
OUTPUT_DIR = DATA_DIR / "output"
DELTA_DISPONIBLE = OUTPUT_DIR / "delta" / "disponibilite"
STATIONS_CSV = DATA_DIR / "velib" / "stations_info.csv"
MODELS_DIR = OUTPUT_DIR / "models"
MLFLOW_DIR = OUTPUT_DIR / "mlruns"
MLFLOW_DB = MLFLOW_DIR / "mlflow.db"  # backend SQLite (MLflow 3.x)

assert DELTA_DISPONIBLE.exists(), (
    f"Table Delta manquante : {DELTA_DISPONIBLE.resolve()}\n"
    "Exécutez les Sessions 2–3 avant ce notebook."
)
assert STATIONS_CSV.exists(), f"Fichier manquant : {STATIONS_CSV.resolve()}"

for dossier in [MODELS_DIR, MLFLOW_DIR]:
    dossier.mkdir(parents=True, exist_ok=True)

APP_NAME = "ClimaCity-Paris-Jour3"
SHUFFLE_PARTS = 8
SEED = 42

print(f"[OK] DATA_DIR         : {DATA_DIR.resolve()}")
print(f"[OK] DELTA_DISPONIBLE : {DELTA_DISPONIBLE.resolve()}")
print(f"[OK] STATIONS_CSV     : {STATIONS_CSV.resolve()}")
# Out:
# [OK] DATA_DIR         : /Users/romain/Desktop/DATA2/SparkVelib/data
# [OK] DELTA_DISPONIBLE : /Users/romain/Desktop/DATA2/SparkVelib/data/output/delta/disponibilite
# [OK] STATIONS_CSV     : /Users/romain/Desktop/DATA2/SparkVelib/data/velib/stations_info.csv

# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.window import Window
from delta import configure_spark_with_delta_pip

_builder = (
    SparkSession.builder
    .appName(APP_NAME)
    .master("local[*]")
    .config("spark.sql.shuffle.partitions", str(SHUFFLE_PARTS))
    .config("spark.driver.memory", "6g")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config(
        "spark.sql.catalog.spark_catalog",
        "org.apache.spark.sql.delta.catalog.DeltaCatalog",
    )
    .config("spark.ui.showConsoleProgress", "false")
)
spark = configure_spark_with_delta_pip(_builder).getOrCreate()
sc = spark.sparkContext
sc.setLogLevel("WARN")

print(f"Spark {spark.version} — Delta Lake activé — http://localhost:4040")
# Out:
# :: loading settings :: url = jar:file:/Users/romain/Desktop/DATA2/SparkVelib/.venv-spark/lib/python3.12/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/romain/.ivy2/cache
# The jars for the packages stored in: /Users/romain/.ivy2/jars
# io.delta#delta-spark_2.12 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-e324cb11-03b9-4915-9986-ff3d61c2e03e;1.0
# 	confs: [default]
# 	found io.delta#delta-spark_2.12;3.2.1 in central
# 	found io.delta#delta-storage;3.2.1 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# :: resolution report :: resolve 64ms :: artifacts dl 2ms
# 	:: modules in use:
# 	io.delta#delta-spark_2.12;3.2.1 from central in [default]
# 	io.delta#delta-storage;3.2.1 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |   3   |   0   |   0   |   0   ||   3   |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-e324cb11-03b9-4915-9986-ff3d61c2e03e
# 	confs: [default]
# 	0 artifacts copied, 3 already retrieved (0kB/2ms)
# 26/09/23 19:06:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/09/23 19:06:10 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 26/09/23 19:06:10 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# Spark 3.5.9 — Delta Lake activé — http://localhost:4040

# %%
# Chargement de la table Delta consolidée (Sessions 2–3)
df = (
    spark.read.format("delta")
    .load(str(DELTA_DISPONIBLE.resolve()))
)
df.cache()
df.count()  # force le cache

print(f"Table consolidée : {df.count():,} lignes  |  {len(df.columns)} colonnes")
df.printSchema()
# Out:
# 26/09/23 19:06:13 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Table consolidée : 690,945 lignes  |  20 colonnes
# root
#  |-- station_id: long (nullable = true)
#  |-- nom_station: string (nullable = true)
#  |-- code_arr: integer (nullable = true)
#  |-- capacite: integer (nullable = true)
#  |-- horodatage: string (nullable = true)
#  |-- velos_meca: integer (nullable = true)
#  |-- velos_elec: integer (nullable = true)
#  |-- bornettes_libres: integer (nullable = true)
#  |-- taux_occupation: double (nullable = true)
#  |-- statut: string (nullable = true)
#  |-- jour_sem: integer (nullable = true)
#  |-- heure: integer (nullable = true)
#  |-- est_weekend: boolean (nullable = true)
#  |-- temperature_c: double (nullable = true)
#  |-- humidite_pct: integer (nullable = true)
#  |-- vent_kmh: double (nullable = true)
#  |-- precipitation_mm: double (nullable = true)
#  |-- est_pluie: boolean (nullable = true)
#  |-- annee: integer (nullable = true)
#  |-- mois: integer (nullable = true)

# %% [markdown]
# ---
# # PARTIE 1 -- Apprentissage automatique avec MLlib
#
# ## 1.1 Les trois abstractions fondamentales de MLlib
#
# MLlib repose sur trois interfaces qui permettent de construire des pipelines
# ML reproductibles et composables.
#
# ### Transformer
#
# Un `Transformer` prend un DataFrame en entrée et retourne un DataFrame enrichi.
# Il implémente la méthode `transform(df)`.
# Exemples : `VectorAssembler`, `StandardScaler` (après fit), `Binarizer`.
#
# ### Estimator
#
# Un `Estimator` est un algorithme qui s'entraîne sur des données.
# Il implémente la méthode `fit(df)` et retourne un `Transformer` (le modèle ajusté).
# Exemples : `GBTRegressor`, `KMeans`, `StandardScaler` (avant fit).
#
# ### Pipeline
#
# Un `Pipeline` enchaîne une liste ordonnée de `Transformer` et d'`Estimator`.
# Lorsqu'on appelle `pipeline.fit(df)`, chaque étape est exécutée en séquence.
# Le résultat est un `PipelineModel`, qui lui-même est un `Transformer`.
#
# ```
# DataFrame d'entrée
#       │
#       ▼
#   Étape 1 : VectorAssembler  (Transformer)  → features brutes
#       │
#       ▼
#   Étape 2 : StandardScaler   (Estimator)    → calcule mean/std sur train
#       │         ↓ fit → StandardScalerModel (Transformer)
#       ▼
#   Étape 3 : GBTRegressor     (Estimator)    → entraîne le modèle
#                 ↓ fit → GBTRegressionModel  (Transformer)
#       │
#       ▼
# DataFrame de sortie (avec colonne "prediction")
# ```
#
# La clé du Pipeline : on appelle `fit()` **une seule fois** sur les données
# d'entraînement. Le `PipelineModel` résultant peut être appliqué sur les données
# de test **sans risque de fuite d'information** entre train et test.

# %% [markdown]
# ---
# ## 1.2 Construction des features
#
# Un bon modèle commence par de bonnes features. Nous allons construire
# un vecteur de features à partir des informations disponibles :
# contexte temporel, conditions météorologiques, et historique récent de la station.

# %%
from pyspark.sql.functions import (
    col, sin, cos, lit, lag, lead, coalesce,
    avg as spark_avg,
    round as spark_round,
)
from pyspark.sql.window import Window
import math

# ── 1. Features temporelles cycliques ────────────────────────────────────────
# L'heure 23 et l'heure 0 sont proches dans le temps mais éloignées en valeur
# brute. On encode l'heure, le jour de semaine et le mois sur un cercle (sin/cos).

PI = math.pi

df_feat = (
    df
    .withColumn("heure_sin", sin(lit(2 * PI) * col("heure") / lit(24)))
    .withColumn("heure_cos", cos(lit(2 * PI) * col("heure") / lit(24)))
    .withColumn("jour_sem_sin", sin(lit(2 * PI) * col("jour_sem") / lit(7)))
    .withColumn("jour_sem_cos", cos(lit(2 * PI) * col("jour_sem") / lit(7)))
    .withColumn("mois_sin", sin(lit(2 * PI) * col("mois") / lit(12)))
    .withColumn("mois_cos", cos(lit(2 * PI) * col("mois") / lit(12)))
    .withColumn("est_weekend_int", col("est_weekend").cast("int"))
)

# ── 2. Features météo (imputation + normalisation simple) ────────────────────
# coalesce remplace les NULL par des constantes raisonnables (climat parisien).
# La normalisation ramène les grandeurs dans des ordres de grandeur comparables ;
# le StandardScaler du pipeline fera le centrage/réduction final.

df_feat = (
    df_feat
    .withColumn(
        "temp_norm",
        coalesce(col("temperature_c"), lit(12.0)) / lit(40.0),
    )
    .withColumn(
        "humidite_norm",
        coalesce(col("humidite_pct").cast("double"), lit(70.0)) / lit(100.0),
    )
    .withColumn(
        "vent_norm",
        coalesce(col("vent_kmh"), lit(10.0)) / lit(50.0),
    )
    .withColumn(
        "precip_norm",
        coalesce(col("precipitation_mm"), lit(0.0)) / lit(10.0),
    )
    .withColumn(
        "est_pluie_int",
        coalesce(col("est_pluie").cast("int"), lit(0)),
    )
)

# ── 3. Features de lag (historique récent de la station) ─────────────────────
fenetre_station = (
    Window
    .partitionBy("station_id")
    .orderBy("horodatage")
)
fenetre_moy_4 = fenetre_station.rowsBetween(-4, -1)

df_feat = (
    df_feat
    .withColumn("taux_lag1", lag("taux_occupation", 1).over(fenetre_station))
    .withColumn("taux_lag4", lag("taux_occupation", 4).over(fenetre_station))
    .withColumn("taux_moy_4", spark_avg("taux_occupation").over(fenetre_moy_4))
)

# ── 4. Variable cible : taux_occupation à t+4 (≈ 1 heure dans le futur) ──────
df_feat = df_feat.withColumn(
    "cible",
    lead("taux_occupation", 4).over(fenetre_station),
)

# ── 5. Suppression des lignes incomplètes (lag/lead génère des nulls) ──────────
FEATURES = [
    "heure_sin", "heure_cos",
    "jour_sem_sin", "jour_sem_cos",
    "mois_sin", "mois_cos",
    "est_weekend_int",
    "temp_norm", "humidite_norm", "vent_norm", "precip_norm", "est_pluie_int",
    "taux_lag1", "taux_lag4", "taux_moy_4",
]

df_ml = df_feat.dropna(subset=FEATURES + ["cible"])

print(f"Lignes disponibles pour le ML : {df_ml.count():,}")
print(f"Features ({len(FEATURES)}) : {FEATURES}")
# Out:
# Lignes disponibles pour le ML : 681,454
# Features (15) : ['heure_sin', 'heure_cos', 'jour_sem_sin', 'jour_sem_cos', 'mois_sin', 'mois_cos', 'est_weekend_int', 'temp_norm', 'humidite_norm', 'vent_norm', 'precip_norm', 'est_pluie_int', 'taux_lag1', 'taux_lag4', 'taux_moy_4']

# %% [markdown]
# ## 1.3 Séparation du jeu de données
#
# Créer un jeu de données pour l'entraînement et un jeu de données pour la validation/test

# %%
# ── 6. Split train / test ──────────────────────────────────────────────────────
# IMPORTANT : on split dans le temps, pas aléatoirement.
# Un split aléatoire sur des séries temporelles entraîne une fuite d'information :
# le modèle voit des données du futur pendant l'entraînement.

annees = sorted(
    row.annee for row in df_ml.select("annee").distinct().collect()
    if row.annee is not None
)
print(f"Années disponibles : {annees}")

if 2022 in annees and 2023 in annees:
    df_train = df_ml.filter(col("annee") == 2022)
    df_test = df_ml.filter(col("annee") == 2023)
    libelle_train, libelle_test = "2022", "2023"
elif len(annees) >= 2:
    # Dernière année = test, années précédentes = train
    annee_test = annees[-1]
    df_train = df_ml.filter(col("annee") < annee_test)
    df_test = df_ml.filter(col("annee") == annee_test)
    libelle_train = "+".join(str(a) for a in annees[:-1])
    libelle_test = str(annee_test)
else:
    # Une seule année : split temporel 85 / 15
    fenetre_ordre = Window.orderBy("horodatage")
    df_ranked = df_ml.withColumn(
        "rang_temporel",
        F.percent_rank().over(fenetre_ordre),
    )
    df_train = df_ranked.filter(col("rang_temporel") < 0.85).drop("rang_temporel")
    df_test = df_ranked.filter(col("rang_temporel") >= 0.85).drop("rang_temporel")
    libelle_train, libelle_test = "85% début", "15% fin"

n_train = df_train.count()
n_test = df_test.count()
n_total = df_ml.count()

print(f"Train ({libelle_train}) : {n_train:,} lignes")
print(f"Test  ({libelle_test}) : {n_test:,} lignes")
print(f"Ratio        : {n_train / n_total:.1%} / {n_test / n_total:.1%}")

# Mise en cache des deux splits -- ils seront accédés plusieurs fois
df_train.cache()
df_train.count()
df_test.cache()
df_test.count()
# Out:
# Années disponibles : [2020, 2021, 2022]
# Train (2020+2021) : 681,408 lignes
# Test  (2022) : 46 lignes
# Ratio        : 100.0% / 0.0%
# 46

# %% [markdown]
# ## 1.4 Clustering des stations avec K-Means
#
# Avant de prédire la disponibilité individuelle de chaque station, nous allons
# **regrouper les stations par profil comportemental** : certaines sont saturées
# le matin (quartiers résidentiels qui "envoient" des cyclistes vers le centre),
# d'autres le soir, d'autres ont un usage homogène sur la journée.
#
# Ce clustering a deux utilités :
# 1. Comprendre la géographie fonctionnelle du réseau.
# 2. Ajouter l'identifiant de cluster comme feature dans le modèle de régression.
#
# ### Construction du profil de station
#
# Le vecteur de profil d'une station est son **taux d'occupation moyen à chaque
# heure de la journée** -- un vecteur de dimension 24.

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.clustering import KMeans
from pyspark.ml.pipeline import Pipeline
# ── Profil horaire moyen par station ─────────────────────────────────────────
# Pivot : une ligne par station, une colonne par heure

df_profil = (
    df_ml
    .groupBy("station_id")
    .pivot("heure", list(range(24)))
    .agg(spark_round(spark_avg("taux_occupation"), 4))
)

# Renommage des colonnes pivot (0 -> h00, 1 -> h01, ...)
for h in range(24):
    df_profil = df_profil.withColumnRenamed(str(h), f"h{h:02d}")

colonnes_profil = [f"h{h:02d}" for h in range(24)]
df_profil = df_profil.dropna(subset=colonnes_profil)

print(f"Stations avec profil complet : {df_profil.count()}")
df_profil.show(5, truncate=True)
# Out:
# Stations avec profil complet : 665
# +----------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+
# |station_id|   h00|   h01|   h02|   h03|   h04|   h05|   h06|   h07|   h08|   h09|   h10|   h11|   h12|   h13|   h14|   h15|   h16|   h17|   h18|   h19|   h20|   h21|   h22|   h23|
# +----------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+
# |     30730|0.0739|0.0769|0.0754|0.0783|0.0787|0.0694|0.0701|0.0741|0.0694|0.0655|0.0634|0.0642|0.0754|0.0568|0.0609|0.0583|0.0661|0.0521|0.0595|0.0596|0.0569|0.0622|0.0659|0.0662|
# |     36255|0.0922|0.0884|0.0762|0.0692|0.0873|0.0793|0.0889|0.0714|0.0708| 0.071| 0.074|0.0706|0.0739|0.0793|0.0788|0.0734|0.0771|0.0801|0.0787|0.0762|0.0784|0.0793|0.0842|0.0816|
# |     52329| 0.056|0.0582| 0.056|0.0577|0.0578|0.0585|0.0568|0.0626|0.0562|0.0597|0.0578|0.0555|0.0601|0.0561|0.0565|0.0555|0.0531| 0.056| 0.062|0.0577|0.0567|0.0571|0.0569|0.0591|
# |  13105968| 0.079|0.0816|0.0842|0.0697|0.0659|0.0643|0.0661|0.0714| 0.064| 0.072|0.0676| 0.071|0.0714|0.0687|0.0694|0.0691|0.0703|0.0673|0.0684|0.0714|0.0734|0.0747|0.0729|0.0745|
# |  13372702|0.0526|0.0548|0.0514|0.0554|0.0575|0.0534|0.0472|0.0579|0.0647|0.0684|0.0585|  0.05|0.0505|0.0491|0.0478|0.0455|0.0443|  0.04|0.0482|0.0529|0.0516|0.0532| 0.061|0.0505|
# +----------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+------+
# only showing top 5 rows

# %%
# ── Méthode du coude : inertie (WSSSE) en fonction de k ──────────────────────
# On entraîne un K-Means pour k = 2..8 et on trace l'inertie.
# Le "coude" dans la courbe indique le bon compromis.

# VectorAssembler : colonnes h00..h23 → un seul vecteur
assembler_profil = VectorAssembler(
    inputCols=colonnes_profil,
    outputCol="features_profil",
)

# StandardScaler : centrage + réduction (moyenne 0, écart-type 1)
scaler_profil = StandardScaler(
    inputCol="features_profil",
    outputCol="features_scaled",
    withStd=True,
    withMean=True,
)

inertie_par_k = {}

for k in range(2, 9):
    kmeans = KMeans(
        featuresCol="features_scaled",
        predictionCol="cluster",
        k=k,
        seed=SEED,
        maxIter=30,
    )
    pipeline_km = Pipeline(stages=[assembler_profil, scaler_profil, kmeans])
    model_km = pipeline_km.fit(df_profil)

    # WSSSE = Within Set Sum of Squared Errors (inertie intra-cluster)
    wssse = model_km.stages[-1].summary.trainingCost
    inertie_par_k[k] = round(wssse, 2)
    print(f"  k={k}  inertie={wssse:,.1f}")

print("\nTableau récapitulatif :")
for k, w in inertie_par_k.items():
    barre = "=" * int(w / max(inertie_par_k.values()) * 40)
    print(f"  k={k}  {w:>12,.1f}  {barre}")
# Out:
# 26/09/23 19:06:27 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/09/23 19:06:27 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.VectorBLAS
#   k=2  inertie=9,905.6
#   k=3  inertie=8,391.9
#   k=4  inertie=7,811.6
#   k=5  inertie=7,183.9
#   k=6  inertie=6,857.2
#   k=7  inertie=6,619.0
#   k=8  inertie=6,417.3
#
# Tableau récapitulatif :
#   k=2       9,905.6  ========================================
#   k=3       8,391.9  =================================
#   k=4       7,811.6  ===============================
#   k=5       7,183.9  =============================
#   k=6       6,857.2  ===========================
#   k=7       6,619.0  ==========================
#   k=8       6,417.3  =========================

# %%
# ── Entraînement final avec le k retenu ───────────────────────────────────────
# Choisissez le k correspondant au "coude" observé ci-dessus.
# En pratique sur ce jeu de données, k=4 ou k=5 est souvent pertinent.
K_RETENU = 4

kmeans_final = KMeans(
    featuresCol="features_scaled",
    predictionCol="cluster",
    k=K_RETENU,
    seed=SEED,
    maxIter=50,
)
pipeline_km_final = Pipeline(
    stages=[assembler_profil, scaler_profil, kmeans_final]
)
model_km_final = pipeline_km_final.fit(df_profil)

# DataFrame station_id → cluster
df_clusters = (
    model_km_final.transform(df_profil)
    .select("station_id", "cluster")
)

print(f"Répartition des {df_clusters.count()} stations en {K_RETENU} clusters :")
(
    df_clusters
    .groupBy("cluster")
    .agg(F.count("*").alias("nb_stations"))
    .orderBy("cluster")
    .show()
)
# Out:
# Répartition des 665 stations en 4 clusters :
# +-------+-----------+
# |cluster|nb_stations|
# +-------+-----------+
# |      0|        193|
# |      1|        148|
# |      2|        189|
# |      3|        135|
# +-------+-----------+

# %%
# ── Interprétation : profil horaire moyen par cluster ────────────────────────

print("Taux d'occupation moyen par cluster et par heure (6h, 9h, 12h, 18h, 22h) :")
(
    df_profil
    .join(df_clusters, on="station_id", how="inner")
    .groupBy("cluster")
    .agg(
        spark_round(spark_avg("h06"), 3).alias("h06"),
        spark_round(spark_avg("h09"), 3).alias("h09"),
        spark_round(spark_avg("h12"), 3).alias("h12"),
        spark_round(spark_avg("h18"), 3).alias("h18"),
        spark_round(spark_avg("h22"), 3).alias("h22"),
        F.count("*").alias("nb_stations"),
    )
    .orderBy("cluster")
    .show()
)
# Out:
# Taux d'occupation moyen par cluster et par heure (6h, 9h, 12h, 18h, 22h) :
# +-------+-----+-----+-----+-----+-----+-----------+
# |cluster|  h06|  h09|  h12|  h18|  h22|nb_stations|
# +-------+-----+-----+-----+-----+-----+-----------+
# |      0|0.054|0.053|0.053|0.053|0.053|        193|
# |      1|0.077|0.072|0.071|0.072|0.075|        148|
# |      2|0.061|0.064|0.064|0.064|0.063|        188|
# |      3|0.069|0.059|0.056|0.061|0.066|        135|
# +-------+-----+-----+-----+-----+-----+-----------+

# %% [markdown]
# ## Folium
#
# Folium s'appuie sur les points forts de l'écosystème Python en termes d'analyse
# de données et sur ceux de la bibliothèque JS Leaflet pour l'affichage cartographique.
# Manipulez vos données en Python, puis visualisez-les dans une carte via Folium.
#
# ### Concepts
#
# Folium facilite la visualisation des données manipulées en Python sur une carte
# interactive. Il permet à la fois la liaison de données avec une carte géographique
# pour les visualisations choroplèthes, et de passer comme marqueurs des graphismes
# riches vectoriels / binaires / HTML.
#
# La bibliothèque dispose d'un certain nombre de jeux de tuiles intégrés
# d'OpenStreetMap, Mapbox, etc. Elle prend aussi en charge les jeux de tuiles personnalisés.
#
# Folium prend en charge les superpositions Image, Video, GeoJSON et TopoJSON et
# dispose d'un nombre de couches vectorielles intégrées.

# %%
# ── Visualisation sur carte Folium ─────────────────────────────────────────
import pandas as pd

try:
    import folium
except ModuleNotFoundError as exc:
    raise ModuleNotFoundError(
        "Le module 'folium' est requis pour cette cellule.\n"
        "Installez-le avec : pip install folium"
    ) from exc

PALETTE = [
    "#e74c3c", "#3498db", "#2ecc71", "#f39c12",
    "#9b59b6", "#1abc9c", "#e67e22",
]

# Stations (CSV ; séparateur) jointes aux clusters Spark
df_stations_pd = pd.read_csv(STATIONS_CSV, sep=";")
df_stations_pd = df_stations_pd[["station_id", "lat", "lon", "name"]].copy()

df_clusters_pd = df_clusters.toPandas()
df_carte = df_clusters_pd.merge(df_stations_pd, on="station_id", how="inner")

print(f"Stations cartographiées : {len(df_carte):,}")

carte = folium.Map(
    location=[48.8566, 2.3522],
    zoom_start=12,
    tiles="CartoDB positron",
)

for _, row in df_carte.iterrows():
    couleur = PALETTE[int(row["cluster"]) % len(PALETTE)]
    folium.CircleMarker(
        location=[row["lat"], row["lon"]],
        radius=5,
        color=couleur,
        fill=True,
        fill_color=couleur,
        fill_opacity=0.8,
        popup=folium.Popup(
            f"<b>{row['name']}</b><br>Cluster {int(row['cluster'])}",
            max_width=250,
        ),
        tooltip=f"{row['name']} — cluster {int(row['cluster'])}",
    ).add_to(carte)

# Légende textuelle
legende_html = (
    "<div style='position:fixed;bottom:30px;left:30px;z-index:1000;"
    "background:white;padding:10px;border:1px solid #ccc;font-size:12px'>"
)
for i in range(K_RETENU):
    legende_html += (
        f"<div><span style='display:inline-block;width:14px;height:14px;"
        f"background:{PALETTE[i]};border-radius:50%;margin-right:6px'></span>"
        f"Cluster {i}</div>"
    )
legende_html += "</div>"
carte.get_root().html.add_child(folium.Element(legende_html))

chemin_carte = OUTPUT_DIR / "carte_clusters_velib.html"
carte.save(str(chemin_carte))
print(f"Carte sauvegardée : {chemin_carte.resolve()}")
print("Ouvrez ce fichier dans votre navigateur pour visualiser les clusters.")

carte
# Out:
# Stations cartographiées : 664
# Carte sauvegardée : /Users/romain/Desktop/DATA2/SparkVelib/data/output/carte_clusters_velib.html
# Ouvrez ce fichier dans votre navigateur pour visualiser les clusters.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_664fe277b7a4c75edc675b59c522f3e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&#x27;position:fixed;bottom:30px;left:30px;z-index:1000;background:white;padding:10px;border:1px solid #ccc;font-size:12px&#x27;&gt;&lt;div&gt;&lt;span style=&#x27;display:inline-block;width:14px;height:14px;background:#e74c3c;border-radius:50%;margin-right:6px&#x27;&gt;&lt;/span&gt;Cluster 0&lt;/div&gt;&lt;div&gt;&lt;span style=&#x27;display:inline-block;width:14px;height:14px;background:#3498db;border-radius:50%;margin-right:6px&#x27;&gt;&lt;/span&gt;Cluster 1&lt;/div&gt;&lt;div&gt;&lt;span style=&#x27;display:inline-block;width:14px;height:14px;background:#2ecc71;border-radius:50%;margin-right:6px&#x27;&gt;&lt;/span&gt;Cluster 2&lt;/div&gt;&lt;div&gt;&lt;span style=&#x27;display:inline-block;width:14px;height:14px;background:#f39c12;border-radius:50%;margin-right:6px&#x27;&gt;&lt;/span&gt;Cluster 3&lt;/div&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_664fe277b7a4c75edc675b59c522f3e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_664fe277b7a4c75edc675b59c522f3e2 = L.map(
#                 &quot;map_664fe277b7a4c75edc675b59c522f3e2&quot;,
#                 {
#                     center: [48.8566, 2.3522],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98af216bad60610a1ecb987674ef5936 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98af216bad60610a1ecb987674ef5936.addTo(map_664fe277b7a4c75edc675b59c522f3e2);
#
#
#             var circle_marker_306248b4b011609dd476e86e30bbe57f = L.circleMarker(
#                 [48.848364667777, 2.3997623859813],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#f39c12&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#f39c12&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_664fe277b7a4c75edc675b59c522f3e2);
#
#
#         var popup_5012483f6010dad3140c32e425814a27 = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_fa0526107974a1d161ce3741cc3f026b = $(`&lt;div id=&quot;html_fa0526107974a1d161ce3741cc3f026b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Place de la Nation - Charonne&lt;/b&gt;&lt;br&gt;Cluster 3&lt;/div&gt;`)[0];
#                 popup_5012483f6010dad3140c32e425814a27.setContent(html_fa0526107974a1d161ce3741cc3f026b);
#
#
#
#         circle_marker_306248b4b011609dd476e86e30bbe57f.bindPopup(popup_5012483f6010dad3140c32e425814a27)
#         ;
#
#
#
#
#             circle_marker_306248b4b011609dd476e86e30bbe57f.bindTooltip(
#                 `&lt;div&gt;
#                      Place de la Nation - Charonne — cluster 3
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_61a91ae2355e190364962d917e81ba35 = L.circleMarker(
#                 [48.87929591733507, 2.3373600840568547],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3498db&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3498db&quot;, &quot;fillOpacity&quot;: 0.8, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_664fe277b7a4c75edc675b59c522f3e2);
#
#
#         var popup_f8ce92f6997c853f39acc857b23c44ad = L.popup({
#   &quot;maxWidth&quot;: 250,
# });
#
#
#
#                 var html_afcd4049d66f132b198d08dbffa9d75b = $(`&lt;div id=&quot;html_afcd4049d66f132b198d08dbffa9d75b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;Toudouze - Clauzel&lt;/b&gt;&lt;br&gt;Cluster 1&lt;/div&gt;`)[0];
#                 popup_f8ce92f6997c853f39acc857b23c44ad.setContent(html_afcd4049d66f132b198d08dbffa9d75b);
#
#
#
#         circle_marker_61a91ae2355e190364962d917e81ba35.bindPopup(popup_f8ce92f6997c853f39acc857b23c44ad)
#         ;

# %%
# Ajout du cluster comme feature pour le modèle de régression
df_ml = df_ml.join(df_clusters, on="station_id", how="left").fillna(0, subset=["cluster"])
df_train = df_train.join(df_clusters, on="station_id", how="left").fillna(0, subset=["cluster"])
df_test = df_test.join(df_clusters, on="station_id", how="left").fillna(0, subset=["cluster"])

# Re-cache après jointure (schéma enrichi)
df_train.cache()
df_test.cache()
df_train.count()
df_test.count()

FEATURES = FEATURES + ["cluster"]
print(f"Features après ajout du cluster ({len(FEATURES)}) : {FEATURES}")
# Out:
# Features après ajout du cluster (16) : ['heure_sin', 'heure_cos', 'jour_sem_sin', 'jour_sem_cos', 'mois_sin', 'mois_cos', 'est_weekend_int', 'temp_norm', 'humidite_norm', 'vent_norm', 'precip_norm', 'est_pluie_int', 'taux_lag1', 'taux_lag4', 'taux_moy_4', 'cluster']

# %% [markdown]
# ---
# ## 1.5 Modèle de régression : GBTRegressor
#
# Le **Gradient Boosted Tree Regressor** est un algorithme d'ensemble qui construit
# séquentiellement des arbres de décision, chacun corrigeant les erreurs du précédent.
# C'est l'un des meilleurs algorithmes pour les données tabulaires avec des features
# hétérogènes -- exactement notre cas.
#
# MLlib l'implémente de façon distribuée : chaque arbre est construit en parallèle
# sur les partitions du DataFrame.

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.regression import GBTRegressor
from pyspark.ml.pipeline import Pipeline
from pyspark.ml.evaluation import RegressionEvaluator
import pandas as pd

# ── Construction du Pipeline ──────────────────────────────────────────────────

# 1. Vecteur de features brutes
assembler = VectorAssembler(
    inputCols=FEATURES,
    outputCol="features_brutes",
    handleInvalid="skip",
)

# 2. Normalisation centrée-réduite
scaler = StandardScaler(
    inputCol="features_brutes",
    outputCol="features",
    withStd=True,
    withMean=True,
)

# 3. Gradient Boosted Trees
gbt = GBTRegressor(
    featuresCol="features",
    labelCol="cible",
    predictionCol="prediction",
    maxIter=50,
    maxDepth=5,
    stepSize=0.1,
    seed=SEED,
)

# 4. Pipeline complet
pipeline_gbt = Pipeline(stages=[assembler, scaler, gbt])

# ── Entraînement ──────────────────────────────────────────────────────────────
print("Entraînement du GBTRegressor (peut prendre 1-2 minutes)...")
t0 = time.perf_counter()
model_gbt = pipeline_gbt.fit(df_train)
t_fit = time.perf_counter() - t0
print(f"Entraînement terminé en {t_fit:.1f} s")
# Out:
# Entraînement du GBTRegressor (peut prendre 1-2 minutes)...
# Entraînement terminé en 18.1 s

# %%
# ── Évaluation sur le test set ────────────────────────────────────────────────
evaluator_rmse = RegressionEvaluator(
    labelCol="cible", predictionCol="prediction", metricName="rmse"
)
evaluator_r2 = RegressionEvaluator(
    labelCol="cible", predictionCol="prediction", metricName="r2"
)
evaluator_mae = RegressionEvaluator(
    labelCol="cible", predictionCol="prediction", metricName="mae"
)

df_pred = model_gbt.transform(df_test)

rmse = evaluator_rmse.evaluate(df_pred)
r2 = evaluator_r2.evaluate(df_pred)
mae = evaluator_mae.evaluate(df_pred)

print("Métriques sur le test set :")
print(f"  RMSE (Root Mean Squared Error) : {rmse:.4f}")
print(f"  MAE  (Mean Absolute Error)     : {mae:.4f}")
print(f"  R²   (coefficient de détermination) : {r2:.4f}")
print()
print("Interprétation :")
print(f"  En moyenne, le modèle se trompe de ±{mae:.3f} sur le taux d'occupation (0-1).")
print(f"  Soit ±{mae * 100:.1f} points de pourcentage.")
# Out:
# Métriques sur le test set :
#   RMSE (Root Mean Squared Error) : 0.0145
#   MAE  (Mean Absolute Error)     : 0.0100
#   R²   (coefficient de détermination) : -0.4751
#
# Interprétation :
#   En moyenne, le modèle se trompe de ±0.010 sur le taux d'occupation (0-1).
#   Soit ±1.0 points de pourcentage.

# %%
# ── Importance des features ────────────────────────────────────────────────────
# Le GBT calcule l'importance de chaque feature (réduction d'impureté moyenne)
import pandas as pd

model_gbt_stage = model_gbt.stages[-1]  # le GBTRegressionModel
importances = model_gbt_stage.featureImportances.toArray()

df_importance = (
    pd.DataFrame({
        "feature": FEATURES,
        "importance": importances,
    })
    .sort_values("importance", ascending=False)
    .reset_index(drop=True)
)

print("Importance des features (top 10) :")
print(f"{'Rang':<5} {'Feature':<25} {'Importance':>12}  Barre")
print("-" * 65)
for i, row in df_importance.head(10).iterrows():
    barre = "█" * int(row["importance"] * 200)
    print(f"  {i + 1:<3} {row['feature']:<25} {row['importance']:>12.4f}  {barre}")
# Out:
# Importance des features (top 10) :
# Rang  Feature                     Importance  Barre
# -----------------------------------------------------------------
#   1   taux_moy_4                      0.3461  █████████████████████████████████████████████████████████████████████
#   2   cluster                         0.1475  █████████████████████████████
#   3   taux_lag1                       0.1341  ██████████████████████████
#   4   heure_cos                       0.1227  ████████████████████████
#   5   heure_sin                       0.0788  ███████████████
#   6   taux_lag4                       0.0753  ███████████████
#   7   mois_sin                        0.0191  ███
#   8   humidite_norm                   0.0141  ██
#   9   jour_sem_cos                    0.0124  ██
#   10  vent_norm                       0.0122  ██

# %%
# ── Analyse des erreurs : où le modèle se trompe-t-il le plus ? ───────────────
df_erreurs = (
    df_pred
    .withColumn("erreur_abs", F.abs(col("prediction") - col("cible")))
    .withColumn("erreur_rel",
        F.abs(col("prediction") - col("cible")) / (col("cible") + F.lit(0.01))
    )
)

print("Erreur absolue moyenne par heure de la journée :")
(
    df_erreurs
    .groupBy("heure")
    .agg(
        spark_round(spark_avg("erreur_abs"), 4).alias("mae_horaire"),
        F.count("*").alias("n")
    )
    .orderBy("heure")
    .show(24)
)
# Out:
# Erreur absolue moyenne par heure de la journée :
# +-----+-----------+---+
# |heure|mae_horaire|  n|
# +-----+-----------+---+
# |    0|     0.0101| 13|
# |    1|     0.0102|  5|
# |    2|       0.01|  5|
# |    3|       0.01|  5|
# |    4|     0.0099| 10|
# |    5|     0.0031|  2|
# |   23|     0.0123|  6|
# +-----+-----------+---+

# %%
# [EXERCICE]
# Calculez l'erreur absolue moyenne (MAE) par cluster de station.
# Quel cluster est le plus difficile à prédire ? Pourquoi, à votre avis ?
#
# Indice : groupBy("cluster").agg(...)
# ──────────────────────────────────────────────────────────────────────────

# Votre code ici :
(
    df_erreurs
    .groupBy("cluster")
    .agg(
        spark_round(spark_avg("erreur_abs"), 4).alias("mae_cluster"),
        spark_round(spark_avg("erreur_rel"), 4).alias("mare_cluster"),
        F.count("*").alias("n_predictions"),
    )
    .orderBy(F.desc("mae_cluster"))
    .show()
)
# Out:
# +-------+-----------+------------+-------------+
# |cluster|mae_cluster|mare_cluster|n_predictions|
# +-------+-----------+------------+-------------+
# |      0|       0.01|       0.104|           46|
# +-------+-----------+------------+-------------+

# %%
# [CORRECTION]
print("MAE par cluster de station :")
(
    df_erreurs
    .groupBy("cluster")
    .agg(
        spark_round(spark_avg("erreur_abs"), 4).alias("mae_cluster"),
        spark_round(spark_avg("erreur_rel"), 4).alias("mare_cluster"),
        F.count("*").alias("n_predictions")
    )
    .orderBy(F.desc("mae_cluster"))
    .show()
)
# Les stations de cluster à fort usage (très vides le matin, très pleines le soir)
# sont généralement plus difficiles à prédire car leur dynamique est plus abrupte.
# Out:
# MAE par cluster de station :
# +-------+-----------+------------+-------------+
# |cluster|mae_cluster|mare_cluster|n_predictions|
# +-------+-----------+------------+-------------+
# |      0|       0.01|       0.104|           46|
# +-------+-----------+------------+-------------+

# %% [markdown]
# ---
# ## 1.6 Validation croisée et optimisation des hyperparamètres
#
# Nos hyperparamètres actuels (`maxIter=50`, `maxDepth=5`, `stepSize=0.1`)
# ont été choisis arbitrairement. Le `CrossValidator` de MLlib permet
# d'évaluer systématiquement plusieurs combinaisons et de choisir la meilleure.
#
# > **Attention** : la validation croisée sur des séries temporelles est
# > délicate. Le `CrossValidator` de MLlib effectue un K-Fold standard
# > (mélanges aléatoires des données), ce qui peut créer de la fuite
# > d'information temporelle. Pour un usage production, on préférerait
# > une validation en fenêtre glissante (*time series split*).
# > Dans le contexte de ce cours, le K-Fold est acceptable pour comprendre
# > le mécanisme.

# %%
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# ── Grille d'hyperparamètres ──────────────────────────────────────────────────
param_grid = (
    ParamGridBuilder()
    .addGrid(gbt.maxDepth,  [3, 5])
    .addGrid(gbt.maxIter,   [30, 50])
    .addGrid(gbt.stepSize,  [0.05, 0.1])
    .build()
)
print(f"Combinaisons à évaluer : {len(param_grid)}")

# ── CrossValidator ────────────────────────────────────────────────────────────
cv = CrossValidator(
    estimator=pipeline_gbt,
    estimatorParamMaps=param_grid,
    evaluator=evaluator_rmse,
    numFolds=3,
    seed=SEED,
    parallelism=2    # évalue 2 combinaisons en parallèle
)

# On entraîne sur un sous-échantillon pour limiter le temps de calcul en cours
df_train_sample = df_train.sample(fraction=0.3, seed=SEED).cache()
df_train_sample.count()
print(f"Sous-échantillon train : {df_train_sample.count():,} lignes")

print("\nValidation croisée en cours (peut prendre 3-5 minutes)...")
t0 = time.perf_counter()
cv_model = cv.fit(df_train_sample)
t_cv = time.perf_counter() - t0
print(f"Terminé en {t_cv:.1f} s")
# Out:
# Combinaisons à évaluer : 8
# Sous-échantillon train : 204,777 lignes
#
# Validation croisée en cours (peut prendre 3-5 minutes)...
# Terminé en 143.3 s

# %%
import pandas as pd

# ── Résultats de la grille ────────────────────────────────────────────────────
avg_metrics = cv_model.avgMetrics
params_list = [
    {p.name: v for p, v in zip(param_grid[0].keys(), combo.values())}
    for combo in param_grid
]

resultats_cv = pd.DataFrame(params_list)
resultats_cv["rmse_cv"] = avg_metrics
resultats_cv = resultats_cv.sort_values("rmse_cv").reset_index(drop=True)

print("Résultats du CrossValidator (triés par RMSE croissant) :")
print(resultats_cv.to_string(index=False))

# Meilleurs hyperparamètres
meilleur = resultats_cv.iloc[0]
print(f"\nMeilleure combinaison :")
for col_name in ["maxDepth", "maxIter", "stepSize", "rmse_cv"]:
    print(f"  {col_name:<12} : {meilleur[col_name]}")
# Out:
# Résultats du CrossValidator (triés par RMSE croissant) :
#  maxDepth  maxIter  stepSize  rmse_cv
#         5       50      0.10 0.020060
#         5       30      0.10 0.020095
#         5       50      0.05 0.020109
#         3       50      0.10 0.020137
#         5       30      0.05 0.020151
#         3       30      0.10 0.020195
#         3       50      0.05 0.020215
#         3       30      0.05 0.020281
#
# Meilleure combinaison :
#   maxDepth     : 5.0
#   maxIter      : 50.0
#   stepSize     : 0.1
#   rmse_cv      : 0.0200595852410743

# %%
# Évaluation du meilleur modèle sur le test set complet
df_pred_best = cv_model.bestModel.transform(df_test)

rmse_best = evaluator_rmse.evaluate(df_pred_best)
r2_best   = evaluator_r2.evaluate(df_pred_best)
mae_best  = evaluator_mae.evaluate(df_pred_best)

print("Comparaison modèle initial vs meilleur modèle CV :")
print(f"{'Métrique':<8}  {'Initial':>12}  {'CV Best':>12}  {'Gain':>10}")
print("-" * 46)
print(f"{'RMSE':<8}  {rmse:>12.4f}  {rmse_best:>12.4f}  {rmse - rmse_best:>+10.4f}")
print(f"{'MAE':<8}  {mae:>12.4f}  {mae_best:>12.4f}  {mae - mae_best:>+10.4f}")
print(f"{'R²':<8}  {r2:>12.4f}  {r2_best:>12.4f}  {r2_best - r2:>+10.4f}")
# Out:
# Comparaison modèle initial vs meilleur modèle CV :
# Métrique       Initial       CV Best        Gain
# ----------------------------------------------
# RMSE            0.0145        0.0142     +0.0003
# MAE             0.0100        0.0104     -0.0003
# R²             -0.4751       -0.4139     +0.0612

# %% [markdown]
# # 1.7 Suivi des expériences avec MLflow
#
# MLflow est un outil de tracking d'expériences ML : il enregistre
# hyperparamètres, métriques, artefacts (modèles, graphiques) et permet
# de comparer les runs dans une interface web.
#
# ```bash
# # Pour ouvrir l'interface MLflow dans un terminal séparé :
# mlflow ui --backend-store-uri sqlite:///data/output/mlruns/mlflow.db --port 5000
# # Puis ouvrir http://localhost:5000 dans le navigateur
# ```
#
# > **Note MLflow 3.x** : le backend fichier (`file://.../mlruns`) est en maintenance.
# > On utilise un backend **SQLite** (`sqlite:///.../mlflow.db`).
#
# > **Dépendance** : `pip install mlflow` (déjà listé dans `requirements.txt`).

# %%
import mlflow
import mlflow.spark

# MLflow 3.x : backend SQLite (le file store file:// est désactivé par défaut)
MLFLOW_DIR.mkdir(parents=True, exist_ok=True)
mlflow.set_tracking_uri(f"sqlite:///{MLFLOW_DB.resolve()}")
mlflow.set_experiment("ClimaCity-Paris-GBT")

print(f"MLflow tracking URI : {mlflow.get_tracking_uri()}")
print(f"Base SQLite         : {MLFLOW_DB.resolve()}")
print(f"Expérience          : ClimaCity-Paris-GBT")
# Out:
# MLflow tracking URI : sqlite:////Users/romain/Desktop/DATA2/SparkVelib/data/output/mlruns/mlflow.db
# Base SQLite         : /Users/romain/Desktop/DATA2/SparkVelib/data/output/mlruns/mlflow.db
# Expérience          : ClimaCity-Paris-GBT

# %%
def evaluer_et_logger(
    df_train_fit, df_test_eval,
    max_depth: int, max_iter: int, step_size: float,
    nom_run: str
) -> dict:
    """Entraîne un pipeline GBT, l'évalue et logue les résultats dans MLflow.

    Args:
        df_train_fit  : DataFrame d'entraînement.
        df_test_eval  : DataFrame de test.
        max_depth     : Profondeur maximale des arbres.
        max_iter      : Nombre d'arbres (iterations).
        step_size     : Taux d'apprentissage.
        nom_run       : Nom du run MLflow.

    Returns:
        Dictionnaire avec les métriques calculées sur le test set.
    """
    with mlflow.start_run(run_name=nom_run):
        # ── Paramètres ──
        mlflow.log_params({
            "max_depth" : max_depth,
            "max_iter"  : max_iter,
            "step_size" : step_size,
            "n_features": len(FEATURES),
            "n_train"   : df_train_fit.count(),
            "n_test"    : df_test_eval.count(),
        })

        # ── Entraînement ──
        gbt_run = GBTRegressor(
            featuresCol="features", labelCol="cible",
            predictionCol="prediction",
            maxIter=max_iter, maxDepth=max_depth,
            stepSize=step_size, seed=SEED
        )
        pipeline_run = Pipeline(stages=[assembler, scaler, gbt_run])
        t0    = time.perf_counter()
        model = pipeline_run.fit(df_train_fit)
        t_fit = time.perf_counter() - t0

        # ── Métriques ──
        preds = model.transform(df_test_eval)
        metriques = {
            "rmse"     : evaluator_rmse.evaluate(preds),
            "mae"      : evaluator_mae.evaluate(preds),
            "r2"       : evaluator_r2.evaluate(preds),
            "fit_time" : round(t_fit, 2),
        }
        mlflow.log_metrics(metriques)

        # ── Modèle ──
        mlflow.spark.log_model(model, artifact_path="pipeline_gbt")

        print(f"  [{nom_run}]  RMSE={metriques['rmse']:.4f}  "
              f"R²={metriques['r2']:.4f}  ({t_fit:.1f}s)")
        return metriques

# ── Plusieurs runs pour comparer ──────────────────────────────────────────────
print("Lancement des runs MLflow...")
configs = [
    {"max_depth": 3, "max_iter": 30, "step_size": 0.1,  "nom_run": "shallow-fast"},
    {"max_depth": 5, "max_iter": 50, "step_size": 0.1,  "nom_run": "medium-balanced"},
    {"max_depth": 5, "max_iter": 50, "step_size": 0.05, "nom_run": "medium-slow-lr"},
    {"max_depth": 7, "max_iter": 80, "step_size": 0.05, "nom_run": "deep-thorough"},
]

resultats_mlflow = []
for cfg in configs:
    m = evaluer_et_logger(df_train, df_test, **cfg)
    resultats_mlflow.append({"run": cfg["nom_run"], **m})

print("\nTableau comparatif :")
df_res = pd.DataFrame(resultats_mlflow).sort_values("rmse")
print(df_res.to_string(index=False))
# Out:
# Lancement des runs MLflow...
#   [shallow-fast]  RMSE=0.0141  R²=-0.3800  (7.7s)
#   [medium-balanced]  RMSE=0.0145  R²=-0.4751  (27.6s)
#   [medium-slow-lr]  RMSE=0.0143  R²=-0.4291  (28.1s)
# 26/09/23 19:11:26 WARN DAGScheduler: Broadcasting large task binary with size 1004.7 KiB
# 26/09/23 19:11:26 WARN DAGScheduler: Broadcasting large task binary with size 1009.4 KiB
# 26/09/23 19:11:26 WARN DAGScheduler: Broadcasting large task binary with size 1009.8 KiB
# 26/09/23 19:11:26 WARN DAGScheduler: Broadcasting large task binary with size 1010.6 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1011.6 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1013.8 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1018.4 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1027.4 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1031.9 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1032.4 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1033.1 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1034.1 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1036.4 KiB
# 26/09/23 19:11:27 WARN DAGScheduler: Broadcasting large task binary with size 1040.9 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1049.6 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1053.9 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1054.4 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1055.1 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1056.1 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1058.3 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1062.9 KiB
# 26/09/23 19:11:28 WARN DAGScheduler: Broadcasting large task binary with size 1071.9 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1076.4 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1076.9 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1077.6 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1078.6 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1080.9 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1085.4 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1094.5 KiB
# 26/09/23 19:11:29 WARN DAGScheduler: Broadcasting large task binary with size 1099.1 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1099.6 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1100.3 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1101.3 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1103.5 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1108.1 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1117.1 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1121.8 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1122.2 KiB
# 26/09/23 19:11:30 WARN DAGScheduler: Broadcasting large task binary with size 1123.0 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1123.9 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1126.2 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1130.7 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1139.8 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1144.4 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1144.9 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1145.6 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1146.6 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1148.9 KiB
# 26/09/23 19:11:31 WARN DAGScheduler: Broadcasting large task binary with size 1153.4 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1162.5 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1167.1 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1167.6 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1168.3 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1169.3 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1171.6 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1176.1 KiB
# 26/09/23 19:11:32 WARN DAGScheduler: Broadcasting large task binary with size 1185.2 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1189.8 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1190.3 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1191.0 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1192.0 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1194.2 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1198.8 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1207.8 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1212.5 KiB
# 26/09/23 19:11:33 WARN DAGScheduler: Broadcasting large task binary with size 1213.0 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1213.7 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1214.7 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1216.9 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1221.5 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1230.5 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1235.2 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1235.6 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1236.3 KiB
# 26/09/23 19:11:34 WARN DAGScheduler: Broadcasting large task binary with size 1237.3 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1239.6 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1244.1 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1253.2 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1257.8 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1258.3 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1259.0 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1260.0 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1262.3 KiB
# 26/09/23 19:11:35 WARN DAGScheduler: Broadcasting large task binary with size 1266.8 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1275.9 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1280.5 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1281.0 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1281.7 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1282.7 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1284.9 KiB
# 26/09/23 19:11:36 WARN DAGScheduler: Broadcasting large task binary with size 1289.5 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1298.5 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1302.9 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1303.3 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1304.0 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1305.0 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1307.3 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1311.8 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1320.9 KiB
# 26/09/23 19:11:37 WARN DAGScheduler: Broadcasting large task binary with size 1325.5 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1326.0 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1326.7 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1327.7 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1330.0 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1334.5 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1343.6 KiB
# 26/09/23 19:11:38 WARN DAGScheduler: Broadcasting large task binary with size 1348.1 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1348.6 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1349.3 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1350.3 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1352.6 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1357.1 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1366.2 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1370.7 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1371.1 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1371.9 KiB
# 26/09/23 19:11:39 WARN DAGScheduler: Broadcasting large task binary with size 1372.8 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1375.1 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1379.6 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1388.7 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1393.3 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1393.8 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1394.5 KiB
# 26/09/23 19:11:40 WARN DAGScheduler: Broadcasting large task binary with size 1395.5 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1397.8 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1402.3 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1411.3 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1415.8 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1416.3 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1417.0 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1418.0 KiB
# 26/09/23 19:11:41 WARN DAGScheduler: Broadcasting large task binary with size 1420.3 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1424.8 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1433.8 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1438.3 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1438.8 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1439.5 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1440.5 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1442.8 KiB
# 26/09/23 19:11:42 WARN DAGScheduler: Broadcasting large task binary with size 1447.3 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1456.4 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1461.0 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1461.5 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1462.2 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1463.2 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1465.4 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1470.0 KiB
# 26/09/23 19:11:43 WARN DAGScheduler: Broadcasting large task binary with size 1479.0 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1483.7 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1484.1 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1484.8 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1485.8 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1488.1 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1492.6 KiB
# 26/09/23 19:11:44 WARN DAGScheduler: Broadcasting large task binary with size 1501.7 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1506.1 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1506.6 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1507.3 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1508.3 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1510.6 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1515.1 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1523.9 KiB
# 26/09/23 19:11:45 WARN DAGScheduler: Broadcasting large task binary with size 1528.1 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1528.6 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1529.3 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1530.3 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1532.6 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1537.1 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1546.2 KiB
# 26/09/23 19:11:46 WARN DAGScheduler: Broadcasting large task binary with size 1550.6 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1551.1 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1551.8 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1552.8 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1555.1 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1559.6 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1568.6 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1572.3 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1572.8 KiB
# 26/09/23 19:11:47 WARN DAGScheduler: Broadcasting large task binary with size 1573.5 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1574.5 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1576.8 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1581.3 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1590.4 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1594.9 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1595.3 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1596.1 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1597.0 KiB
# 26/09/23 19:11:48 WARN DAGScheduler: Broadcasting large task binary with size 1599.3 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1603.8 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1612.9 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1617.4 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1617.8 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1618.6 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1619.5 KiB
# 26/09/23 19:11:49 WARN DAGScheduler: Broadcasting large task binary with size 1621.8 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1626.3 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1635.4 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1640.0 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1640.5 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1641.2 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1642.2 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1644.5 KiB
# 26/09/23 19:11:50 WARN DAGScheduler: Broadcasting large task binary with size 1649.0 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1658.1 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1662.7 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1663.2 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1663.9 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1664.9 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1667.1 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1671.7 KiB
# 26/09/23 19:11:51 WARN DAGScheduler: Broadcasting large task binary with size 1680.7 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1685.3 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1685.8 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1686.5 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1687.5 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1689.8 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1694.3 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1703.4 KiB
# 26/09/23 19:11:52 WARN DAGScheduler: Broadcasting large task binary with size 1707.8 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1708.3 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1709.0 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1710.0 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1712.3 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1716.8 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1725.6 KiB
# 26/09/23 19:11:53 WARN DAGScheduler: Broadcasting large task binary with size 1729.9 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1730.3 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1731.1 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1732.1 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1734.3 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1738.9 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1747.9 KiB
# 26/09/23 19:11:54 WARN DAGScheduler: Broadcasting large task binary with size 1752.5 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1753.0 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1753.7 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1754.7 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1757.0 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1761.5 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1770.6 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1775.2 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1775.7 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1776.4 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1777.4 KiB
# 26/09/23 19:11:55 WARN DAGScheduler: Broadcasting large task binary with size 1779.7 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1784.2 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1793.3 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1797.7 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1798.2 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1798.9 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1799.9 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1802.2 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1806.7 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1815.7 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1820.1 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1820.5 KiB
# 26/09/23 19:11:56 WARN DAGScheduler: Broadcasting large task binary with size 1821.3 KiB
# 26/09/23 19:11:57 WARN DAGScheduler: Broadcasting large task binary with size 1822.3 KiB
# 26/09/23 19:11:57 WARN DAGScheduler: Broadcasting large task binary with size 1824.5 KiB
# 26/09/23 19:11:57 WARN DAGScheduler: Broadcasting large task binary with size 1829.0 KiB
# 26/09/23 19:11:57 WARN DAGScheduler: Broadcasting large task binary with size 1838.1 KiB
# 26/09/23 19:11:57 WARN DAGScheduler: Broadcasting large task binary with size 1842.6 KiB
# 26/09/23 19:11:57 WARN DAGScheduler: Broadcasting large task binary with size 1843.1 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1843.8 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1844.8 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1847.0 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1851.6 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1860.7 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1865.2 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1865.7 KiB
# 26/09/23 19:11:58 WARN DAGScheduler: Broadcasting large task binary with size 1866.4 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1867.4 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1869.7 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1874.2 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1883.3 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1887.7 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1888.2 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1888.9 KiB
# 26/09/23 19:11:59 WARN DAGScheduler: Broadcasting large task binary with size 1889.9 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1892.2 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1896.7 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1905.8 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1910.1 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1910.6 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1911.3 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1912.3 KiB
# 26/09/23 19:12:00 WARN DAGScheduler: Broadcasting large task binary with size 1914.5 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1919.0 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1927.8 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1932.1 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1932.6 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1933.3 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1934.3 KiB
# 26/09/23 19:12:01 WARN DAGScheduler: Broadcasting large task binary with size 1936.5 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1941.1 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1950.2 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1954.8 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1955.3 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1956.0 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1957.0 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1959.2 KiB
# 26/09/23 19:12:02 WARN DAGScheduler: Broadcasting large task binary with size 1963.8 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1972.8 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1977.3 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1977.8 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1978.5 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1979.5 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1981.7 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1986.3 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1995.3 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 1999.8 KiB
# 26/09/23 19:12:03 WARN DAGScheduler: Broadcasting large task binary with size 2000.3 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2001.0 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2002.0 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2004.2 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2008.7 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2017.2 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2021.2 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2021.6 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2022.4 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2023.3 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2025.6 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2030.1 KiB
# 26/09/23 19:12:04 WARN DAGScheduler: Broadcasting large task binary with size 2039.2 KiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2043.8 KiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2044.3 KiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2045.0 KiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2046.0 KiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:05 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:06 WARN DAGScheduler: Broadcasting large task binary with size 2.0 MiB
# 26/09/23 19:12:07 WARN DAGScheduler: Broadcasting large task binary with size 2.1 MiB
#   [deep-thorough]  RMSE=0.0137  R²=-0.3042  (68.2s)
#
# Tableau comparatif :
#             run     rmse      mae        r2  fit_time
#   deep-thorough 0.013665 0.009560 -0.304159     68.22
#    shallow-fast 0.014056 0.009889 -0.380003      7.71
#  medium-slow-lr 0.014304 0.009751 -0.429100     28.09
# medium-balanced 0.014532 0.010034 -0.475087     27.59

# %%
# ── Chargement du meilleur modèle depuis MLflow ───────────────────────────────
from mlflow.tracking import MlflowClient

client  = MlflowClient()
exp     = client.get_experiment_by_name("ClimaCity-Paris-GBT")
runs    = client.search_runs(
    experiment_ids=[exp.experiment_id],
    order_by=["metrics.rmse ASC"],
    max_results=1
)
best_run = runs[0]

print(f"Meilleur run :")
print(f"  ID   : {best_run.info.run_id}")
print(f"  Nom  : {best_run.data.tags.get('mlflow.runName', 'N/A')}")
print(f"  RMSE : {best_run.data.metrics['rmse']:.4f}")
print(f"  R²   : {best_run.data.metrics['r2']:.4f}")

# Rechargement du modèle
model_uri     = f"runs:/{best_run.info.run_id}/pipeline_gbt"
model_recharge = mlflow.spark.load_model(model_uri)
print(f"\nModèle rechargé depuis : {model_uri}")

# Vérification : les prédictions sont identiques
df_verif = model_recharge.transform(df_test.limit(100))
rmse_verif = evaluator_rmse.evaluate(df_verif)
print(f"RMSE sur 100 lignes (vérification) : {rmse_verif:.4f}")
# Out:
# Meilleur run :
#   ID   : c0143c8a92af4711b7a21993d50f6a72
#   Nom  : deep-thorough
#   RMSE : 0.0137
#   R²   : -0.3042
# Downloading artifacts:   0%|          | 0/32 [00:00<?, ?it/s]
# 2026/09/23 19:12:16 INFO mlflow.spark: URI 'runs:/c0143c8a92af4711b7a21993d50f6a72/pipeline_gbt/sparkml' does not point to the current DFS.
# 2026/09/23 19:12:16 INFO mlflow.spark: File 'runs:/c0143c8a92af4711b7a21993d50f6a72/pipeline_gbt/sparkml' not found on DFS. Will attempt to upload the file.
# Modèle rechargé depuis : runs:/c0143c8a92af4711b7a21993d50f6a72/pipeline_gbt
# RMSE sur 100 lignes (vérification) : 0.0137

# %%
# Sauvegarde locale du meilleur modèle (format natif Spark)
chemin_model_local = MODELS_DIR / "gbt_best"
cv_model.bestModel.write().overwrite().save(str(chemin_model_local))
print(f"Modèle sauvegardé localement : {chemin_model_local}")

# Pour le recharger plus tard :
# from pyspark.ml.pipeline import PipelineModel
# model_recharge = PipelineModel.load(str(chemin_model_local))
# Out:
# Modèle sauvegardé localement : ../data/output/models/gbt_best
